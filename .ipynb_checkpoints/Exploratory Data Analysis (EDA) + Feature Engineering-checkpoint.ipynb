# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ####  Reading the Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import random

import re
import string
from nltk.corpus import words, stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
# Removing punctuations from the text
import string
import missingno as msno
from textblob import TextBlob
from nltk import FreqDist
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('ASAP Dataset/training_set_rel3.tsv', sep = '\t',
                encoding = 'ISO-8859-1')

# %%
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
# ...

# %%
msno.matrix(df, color = (0.2, 0.5, 0.1))
plt.show()

# %%
df.describe()
# Out:
#            essay_id     essay_set  rater1_domain1  rater2_domain1  \
# count  12976.000000  12976.000000    12976.000000    12976.000000
# mean   10295.395808      4.179485        4.127158        4.137408
# std     6309.074105      2.136913        4.212544        4.264330
# min        1.000000      1.000000        0.000000        0.000000
# 25%     4438.750000      2.000000        2.000000        2.000000
# 50%    10044.500000      4.000000        3.000000        3.000000
# 75%    15681.250000      6.000000        4.000000        4.000000
# max    21633.000000      8.000000       30.000000       30.000000
#
#        rater3_domain1  domain1_score  rater1_domain2  rater2_domain2  \
# count      128.000000   12976.000000     1800.000000     1800.000000
# mean        37.828125       6.800247        3.333889        3.330556
# std          5.240829       8.970705        0.729103        0.726807
# min         20.000000       0.000000        1.000000        1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12976 entries, 0 to 12975
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   essay_id        12976 non-null  int64
#  1   essay_set       12976 non-null  int64
#  2   essay           12976 non-null  object
#  3   rater1_domain1  12976 non-null  int64
#  4   rater2_domain1  12976 non-null  int64
#  5   rater3_domain1  128 non-null    float64
#  6   domain1_score   12976 non-null  int64
#  7   rater1_domain2  1800 non-null   float64
#  8   rater2_domain2  1800 non-null   float64
#  9   domain2_score   1800 non-null   float64
#  10  rater1_trait1   2292 non-null   float64
#  11  rater1_trait2   2292 non-null   float64
#  12  rater1_trait3   2292 non-null   float64
#  13  rater1_trait4   2292 non-null   float64
#  14  rater1_trait5   723 non-null    float64
#  15  rater1_trait6   723 non-null    float64
#  16  rater2_trait1   2292 non-null   float64
# ...

# %%
# Printing the maximum number of characters in the data
df['essay'].apply(lambda x: len(x)).max()
# Out:
# 6098

# %%
# Printing the minimum number of characters in the data
df['essay'].apply(lambda x: len(x)).min()
# Out:
# 8

# %%
# Printing the maximum number of words in the data
df['essay'].apply(lambda x: len(x.split(' '))).max()
# Out:
# 1119

# %%
# Printing the minimum number of words in the data
df['essay'].apply(lambda x: len(x.split(' '))).min()
# Out:
# 2

# %%
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
# ...

# %%
ax = df['essay_set'].value_counts().plot(kind = 'bar', color = 'orange')
for i, v in enumerate(df['essay_set'].value_counts()):
    ax.text(i - 0.1 + 0.4/2, v + 1, str(v), ha='center')
plt.title("Total number of essays for the sets")
plt.xlabel("Set Number")
plt.ylabel("Total Essays")
plt.show()

# %%
df_essay_set1 = df[df.essay_set == 1].copy()
df_essay_set2 = df[df.essay_set == 2].copy()
df_essay_set3 = df[df.essay_set == 3].copy()
df_essay_set4 = df[df.essay_set == 4].copy()
df_essay_set5 = df[df.essay_set == 5].copy()
df_essay_set6 = df[df.essay_set == 6].copy()
df_essay_set7 = df[df.essay_set == 7].copy()
df_essay_set8 = df[df.essay_set == 8].copy()

# %%
fig, axes = plt.subplots(nrows = 4, ncols = 2, figsize = (10, 20))

sns.kdeplot(df_essay_set1['rater1_domain1'], label='rater-1 score', shade=True, ax=axes[0, 0])
sns.kdeplot(df_essay_set1['rater2_domain1'], label='rater-2 score', shade=True, ax=axes[0, 0])
axes[0, 0].set_title('Set 1')
axes[0, 0].set_xlabel("Scores")

sns.kdeplot(df_essay_set2['rater1_domain1'], label='rater-1 score', shade=True, ax=axes[0, 1])
sns.kdeplot(df_essay_set2['rater2_domain1'], label='rater-2 score', shade=True, ax=axes[0, 1])
axes[0, 1].set_title('Set 2')
axes[0, 1].set_xlabel("Scores")

sns.kdeplot(df_essay_set3['rater1_domain1'], label='rater-1 score', shade=True, ax=axes[1, 0])
sns.kdeplot(df_essay_set3['rater2_domain1'], label='rater-2 score', shade=True, ax=axes[1, 0])
axes[1, 0].set_title('Set 3')
axes[1, 0].set_xlabel("Scores")

sns.kdeplot(df_essay_set4['rater1_domain1'], label='rater-1 score', shade=True, ax=axes[1, 1])
sns.kdeplot(df_essay_set4['rater2_domain1'], label='rater-2 score', shade=True, ax=axes[1, 1])
axes[1, 1].set_title('Set 4')
axes[1, 1].set_xlabel("Scores")

sns.kdeplot(df_essay_set5['rater1_domain1'], label='rater-1 score', shade=True, ax=axes[2, 0])
sns.kdeplot(df_essay_set5['rater2_domain1'], label='rater-2 score', shade=True, ax=axes[2, 0])
axes[2, 0].set_title('Set 5')
axes[2, 0].set_xlabel("Scores")

sns.kdeplot(df_essay_set6['rater1_domain1'], label='rater-1 score', shade=True, ax=axes[2, 1])
sns.kdeplot(df_essay_set6['rater2_domain1'], label='rater-2 score', shade=True, ax=axes[2, 1])
axes[2, 1].set_title('Set 6')
axes[2, 1].set_xlabel("Scores")

sns.kdeplot(df_essay_set7['rater1_domain1'], label='rater-1 score', shade=True, ax=axes[3, 0])
sns.kdeplot(df_essay_set7['rater2_domain1'], label='rater-2 score', shade=True, ax=axes[3, 0])
axes[3, 0].set_title('Set 7')
axes[3, 0].set_xlabel("Scores")

sns.kdeplot(df_essay_set8['rater1_domain1'], label='rater-1 score', shade=True, ax=axes[3, 1])
sns.kdeplot(df_essay_set8['rater2_domain1'], label='rater-2 score', shade=True, ax=axes[3, 1])
axes[3, 1].set_title('Set 8')
axes[3, 1].set_xlabel("Scores")

axes[0, 0].legend()
axes[0, 1].legend()
axes[1, 0].legend()
axes[1, 1].legend()
axes[2, 0].legend()
axes[2, 1].legend()
axes[3, 0].legend()
axes[3, 1].legend()

fig.subplots_adjust(hspace = 0.3, wspace = 0.3)

fig.suptitle("Distribution of scores for essay sets among 2 raters", 
            fontsize = 16, fontweight = 'bold')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(10, 20))

sns.boxplot(data=df_essay_set1[['rater1_domain1', 'rater2_domain1']], ax=axes[0, 0])
axes[0, 0].set_title('Set 1')
axes[0, 0].set_xlabel("Raters")
axes[0, 0].set_ylabel("Scores")

sns.boxplot(data=df_essay_set2[['rater1_domain1', 'rater2_domain1']], ax=axes[0, 1])
axes[0, 1].set_title('Set 2')
axes[0, 1].set_xlabel("Raters")
axes[0, 1].set_ylabel("Scores")

sns.boxplot(data=df_essay_set3[['rater1_domain1', 'rater2_domain1']], ax=axes[1, 0])
axes[1, 0].set_title('Set 3')
axes[1, 0].set_xlabel("Raters")
axes[1, 0].set_ylabel("Scores")

sns.boxplot(data=df_essay_set4[['rater1_domain1', 'rater2_domain1']], ax=axes[1, 1])
axes[1, 1].set_title('Set 4')
axes[1, 1].set_xlabel("Raters")
axes[1, 1].set_ylabel("Scores")

sns.boxplot(data=df_essay_set5[['rater1_domain1', 'rater2_domain1']], ax=axes[2, 0])
axes[2, 0].set_title('Set 5')
axes[2, 0].set_xlabel("Raters")
axes[2, 0].set_ylabel("Scores")

sns.boxplot(data=df_essay_set6[['rater1_domain1', 'rater2_domain1']], ax=axes[2, 1])
axes[2, 1].set_title('Set 6')
axes[2, 1].set_xlabel("Raters")
axes[2, 1].set_ylabel("Scores")

sns.boxplot(data=df_essay_set7[['rater1_domain1', 'rater2_domain1']], ax=axes[3, 0])
axes[3, 0].set_title('Set 7')
axes[3, 0].set_xlabel("Raters")
axes[3, 0].set_ylabel("Scores")

sns.boxplot(data=df_essay_set8[['rater1_domain1', 'rater2_domain1']], ax=axes[3, 1])
axes[3, 1].set_title('Set 8')
axes[3, 1].set_xlabel("Raters")
axes[3, 1].set_ylabel("Scores")

fig.subplots_adjust(hspace=0.35, wspace=0.3)

fig.suptitle("Distribution of scores for essay sets among 2 raters",
            fontsize=16, fontweight='bold')
plt.show()

# %%
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
# ...

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Calculating length features

# %%
word_len, chars, avg_word_length, avg_sentence_length = zip(*list(df['essay'].apply(text_length_features)))

df['word_len'] = word_len
df['chars_len'] = chars
df['avg_word_length'] = avg_word_length
df['avg_sentence_length'] = avg_sentence_length

# %% [markdown]
# #### Calculating syntactic features

# %%
# This can take about 5 - 10 minutes to execute depending on the system speed
pos_ratios, num_sentences, num_paragraphs = zip(*list(df['essay'].apply(syntactic_features)))

df['pos_ratios'] = pos_ratios
df['num_sentences'] = num_sentences
df['num_paragraphs'] = num_paragraphs

# %% [markdown]
# #### Calculating polarity scores

# %%
# This can take about 2 - 3 minutes to execute depending on the system speed
sentiment_polarity, sentiment_subjectivity = zip(*list(df['essay'].apply(sentiment_analysis)))

df['sentiment_polariy'] = sentiment_polarity
df['sentiment_subjectivity'] = sentiment_subjectivity

# %%
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  rater3_trait6  \
# ...

# %%
df_essay_set1 = df[df.essay_set == 1].copy()
df_essay_set2 = df[df.essay_set == 2].copy()
df_essay_set3 = df[df.essay_set == 3].copy()
df_essay_set4 = df[df.essay_set == 4].copy()
df_essay_set5 = df[df.essay_set == 5].copy()
df_essay_set6 = df[df.essay_set == 6].copy()
df_essay_set7 = df[df.essay_set == 7].copy()
df_essay_set8 = df[df.essay_set == 8].copy()

# %%
correlation_features = ['word_len', 'chars_len', 'avg_word_length', 'avg_sentence_length',
       'num_sentences', 'sentiment_polariy',
       'sentiment_subjectivity', 'rater1_domain1', 'rater2_domain1']
corr_matrix1 = df_essay_set1[correlation_features].corr()
corr_matrix2 = df_essay_set2[correlation_features].corr()
corr_matrix3 = df_essay_set3[correlation_features].corr()
corr_matrix4 = df_essay_set4[correlation_features].corr()
corr_matrix5 = df_essay_set5[correlation_features].corr()
corr_matrix6 = df_essay_set6[correlation_features].corr()
corr_matrix7 = df_essay_set7[correlation_features].corr()
corr_matrix8 = df_essay_set8[correlation_features].corr()

fig, axs = plt.subplots(4, 2, figsize=(20, 20))

sns.heatmap(corr_matrix1, annot=True, cmap='Blues', ax = axs[0, 0])
axs[0, 0].set_title("Essay Set 1")
sns.heatmap(corr_matrix2, annot = True, cmap = 'Greens', ax = axs[0, 1])
axs[0, 1].set_title("Essay Set 2")
sns.heatmap(corr_matrix3, annot = True, cmap = 'vlag', ax = axs[1, 0])
axs[1, 0].set_title("Essay Set 3")
sns.heatmap(corr_matrix4, annot = True, cmap = 'Purples', ax = axs[1, 1])
axs[1, 1].set_title("Essay Set 4")
sns.heatmap(corr_matrix5, annot = True, cmap = 'Greens', ax = axs[2, 0])
axs[2, 0].set_title("Essay Set 5")
sns.heatmap(corr_matrix6, annot = True, cmap = 'Blues', ax = axs[2, 1])
axs[2, 1].set_title("Essay Set 6")
sns.heatmap(corr_matrix7, annot = True, cmap = 'Reds', ax = axs[3, 0])
axs[3, 0].set_title("Essay Set 7")
sns.heatmap(corr_matrix8, annot = True, cmap = 'Oranges', ax = axs[3, 1])
axs[3, 1].set_title("Essay Set 8")

plt.suptitle("Correlation between Features", fontsize = 15, 
             fontweight = 'bold', y = 1.02)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Text Preprocessing

# %%
def text_preprocessing(text):

    preprocessed_text = remove_words_with_special_tokens(text)
    preprocessed_text = tokenize(preprocessed_text)
    preprocessed_text = lowercase(preprocessed_text)
    preprocessed_text = remove_punctuation(preprocessed_text)
    preprocessed_text = remove_stopwords(preprocessed_text)
    preprocessed_text = lemmatize(preprocessed_text)
    preprocessed_text = remove_special_characters(preprocessed_text)
    
    return ' '.join(preprocessed_text)

# %%
df['preprocessed_text'] = df['essay'].apply(text_preprocessing)

# %%
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  word_len  chars_len  \
# ...

# %%
# df.to_csv('ASAP Dataset/Preprocessed_df.csv', index = False)
