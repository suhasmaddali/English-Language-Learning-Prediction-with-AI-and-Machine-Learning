# %%
# Running a random script to determine if the tensorflow library is using GPU

import numpy as np
import tensorflow as tf

# load MNIST Digit data
data = tf.keras.datasets.mnist

# here data is split into 70,30 by default
(X_train, Y_train), (X_test, Y_test) = data.load_data()

# normalizing data
X_train = tf.keras.utils.normalize(X_train)
X_test = tf.keras.utils.normalize(X_test)

# checking shape of data
print(X_train.shape)
print(X_test.shape)

# function to create and compile model
def createModel(input_shape, num_classes, optimizer, loss, metrics):

    model = tf.keras.models.Sequential()  ##a feed forward model , created stack of layer on top of it
    model.add(tf.keras.layers.Input(shape=input_shape))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

    model.compile(optimizer=optimizer, loss=loss, metrics=[metrics])

    return model

# model
model = createModel(input_shape=(28, 28), num_classes=10, optimizer='adam',
                    loss='sparse_categorical_crossentropy',
                    metrics='accuracy')

model.summary()

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU'))) #print no of GPU device

model.fit(X_train, Y_train, epochs=30, validation_split=0.1)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 76,362
# Trainable params: 76,362
# Non-trainable params: 0
# _________________________________________________________________
# Num GPUs Available:  1
# Epoch 1/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.2924 - accuracy: 0.9106 - val_loss: 0.1329 - val_accuracy: 0.9603
# Epoch 2/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1271 - accuracy: 0.9601 - val_loss: 0.1029 - val_accuracy: 0.9713
# Epoch 3/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0915 - accuracy: 0.9713 - val_loss: 0.0915 - val_accuracy: 0.9727
# Epoch 4/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0700 - accuracy: 0.9776 - val_loss: 0.0905 - val_accuracy: 0.9735
# Epoch 5/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0578 - accuracy: 0.9814 - val_loss: 0.0801 - val_accuracy: 0.9770
# Epoch 6/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0479 - accuracy: 0.9848 - val_loss: 0.0794 - val_accuracy: 0.9782
# Epoch 7/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0408 - accuracy: 0.9868 - val_loss: 0.0900 - val_accuracy: 0.9752
# Epoch 8/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0361 - accuracy: 0.9885 - val_loss: 0.1017 - val_accuracy: 0.9758
# Epoch 9/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0313 - accuracy: 0.9895 - val_loss: 0.0994 - val_accuracy: 0.9743
# Epoch 10/30
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.0277 - accuracy: 0.9908 - val_loss: 0.0978 - val_accuracy: 0.9767
# Epoch 11/30
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.1033 - val_accuracy: 0.9757
# Epoch 12/30
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.0236 - accuracy: 0.9916 - val_loss: 0.1014 - val_accuracy: 0.9762
# Epoch 13/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0212 - accuracy: 0.9930 - val_loss: 0.1036 - val_accuracy: 0.9773
# Epoch 14/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0192 - accuracy: 0.9934 - val_loss: 0.1041 - val_accuracy: 0.9772
# Epoch 15/30
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.1508 - val_accuracy: 0.9697
# Epoch 16/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0177 - accuracy: 0.9938 - val_loss: 0.1017 - val_accuracy: 0.9805
# Epoch 17/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0145 - accuracy: 0.9950 - val_loss: 0.0985 - val_accuracy: 0.9783
# Epoch 18/30
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.1039 - val_accuracy: 0.9792
# Epoch 19/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.1252 - val_accuracy: 0.9772
# Epoch 20/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.1079 - val_accuracy: 0.9795
# Epoch 21/30
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.1210 - val_accuracy: 0.9795
# Epoch 22/30
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.0138 - accuracy: 0.9953 - val_loss: 0.1375 - val_accuracy: 0.9773
# Epoch 23/30
# 1688/1688 [==============================] - 4s 3ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.1449 - val_accuracy: 0.9770
# Epoch 24/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.1286 - val_accuracy: 0.9788
# Epoch 25/30
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.1295 - val_accuracy: 0.9770
# Epoch 26/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.1320 - val_accuracy: 0.9783
# Epoch 27/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.1499 - val_accuracy: 0.9767
# Epoch 28/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.1431 - val_accuracy: 0.9783
# Epoch 29/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.1168 - val_accuracy: 0.9823
# Epoch 30/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.1421 - val_accuracy: 0.9788
